# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({"First":[1,2,3], "Second":[4,5,6]}, index=["a", "b", "c"])
df
# Out:
#    First  Second
# a      1       4
# b      2       5
# c      3       6
